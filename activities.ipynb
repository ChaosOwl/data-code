# %%
import requests
import urllib.error
import urllib.parse
from urllib import request
import json
import pandas as pd
import numpy as np
import re
import time
from datetime import date, datetime

# %%
dataframe = pd.read_excel('table of events and activities.xlsx')

# %%
dataframe.head(3)
# Out:
#                  Activity                          Day  \
# 0     Carer Support Group            Contact organiser
# 1           Carlton Baths                        Daily
# 2  Carlton Farmers Market  First Saturday of the month
#
#                               Category  \
# 0  Social Groups, Health and Wellbeing
# 1                 Health and Wellbeing
# 2                 Health and Wellbeing
#
#                                              Address                  Contact  \
# 0  Kathleen Syme Library and Community Centre 251...                9658 9989
# 1                      248 Rathdowne Street, Carlton                9347 3677
# 2  Carlton North Primary School. Corner Canning a...  9499 3400, 0429 146 627
#
#                                         Website  \
# 0  https://www.melbourne.vic.gov.au/olderpeople
# 1          https://www.carltonbaths.ymca.org.au
# 2                        https://www.mfm.com.au
#
#                                 Email  \
# 0  healthyageing@melbourne.vic.gov.au
# 1            carltonbaths@ymca.org.au
# 2                                 NaN
#
#                                          Description
# 0  Anyone can become a carer at any stage of thei...
# 1  Carlton Baths welcomes members and visitors to...
# 2  Buy your meat, fruit and vegetables as well as...

# %%
dataframe['geocode address'] = ''

# %%
for i in range(len(dataframe)):
    try:
        dataframe['geocode address'][i] = dataframe['Address'][i] + ', Melbourne'
    except TypeError:
        print(i)

# %%
def read_the_url(urllink):
    res = requests.get(urllink)
    js = json.loads(res.text)
    return js



def get_latitude_longtitude(address):
    # decode url
    address = urllib.parse.quote(address)
    url = "https://maps.googleapis.com/maps/api/geocode/json?address=" + address + "&key=" #add your key    
    while True:
        res = requests.get(url)
        js = json.loads(res.text)

        if js["status"] != "OVER_QUERY_LIMIT":
            time.sleep(1)
            break

    result = js["results"][0]["geometry"]["location"]
    lat = result["lat"]
    lng = result["lng"]

    return lat, lng

# %%
dataframe['lat'] = ''
dataframe['lng'] = ''

# %%
for i in range(len(dataframe)):
    address = dataframe['geocode address'][i]
    lat, lng = get_latitude_longtitude(address)
    dataframe['lat'][i] = lat
    dataframe['lng'][i] = lng

# %%
dataframe.head()
# Out:
#                                    Activity                          Day  \
# 0                       Carer Support Group            Contact organiser
# 1                             Carlton Baths                        Daily
# 2                    Carlton Farmers Market  First Saturday of the month
# 3     Carlton Neighbourhood Learning Centre                        Daily
# 4  Carlton Women’s Turkish Group (cohealth)                      Tuesday
#
#                                             Category  \
# 0                Social Groups, Health and Wellbeing
# 1                               Health and Wellbeing
# 2                               Health and Wellbeing
# 3  Arts and culture, Social Groups, Health and We...
# 4                                      Social Groups
#
#                                              Address                  Contact  \
# 0  Kathleen Syme Library and Community Centre 251...                9658 9989
# 1                      248 Rathdowne Street, Carlton                9347 3677
# 2  Carlton North Primary School. Corner Canning a...  9499 3400, 0429 146 627
# 3                         20 Princes Street, Carlton                9347 2739
# 4                          510 Lygon Street, Carlton                9448 6792
#
#                                         Website  \
# 0  https://www.melbourne.vic.gov.au/olderpeople
# 1          https://www.carltonbaths.ymca.org.au
# 2                        https://www.mfm.com.au
# 3                       https://www.cnlc.org.au
# 4                   https://www.cohealth.org.au
#
#                                 Email  \
# 0  healthyageing@melbourne.vic.gov.au
# 1            carltonbaths@ymca.org.au
# 2                                 NaN
# 3                    info@cnlc.org.au
# 4       maria.ibrahim@cohealth.org.au
#
#                                          Description  \
# 0  Anyone can become a carer at any stage of thei...
# 1  Carlton Baths welcomes members and visitors to...
# 2  Buy your meat, fruit and vegetables as well as...
# 3  Take part in a broad and varied program that i...
# 4  Connect and share experiences with other Turki...
#
#                                      geocode address      lat      lng
# 0  Kathleen Syme Library and Community Centre 251... -37.7987  144.965
# 1           248 Rathdowne Street, Carlton, Melbourne -37.7935  144.972
# 2  Carlton North Primary School. Corner Canning a... -37.7911  144.973
# 3              20 Princes Street, Carlton, Melbourne -37.7927  144.975
# 4               510 Lygon Street, Carlton, Melbourne -37.7946  144.968

# %%
class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, datetime):
            return obj.strftime('%Y-%m-%d %H:%M:%S')
        elif isinstance(obj, date):
            return obj.strftime('%Y-%m-%d')
        else:
            return json.JSONEncoder.default(self, obj)

# %%
dataframe.drop(columns=['geocode address'], inplace=True)

# %%
for i in range(len(dataframe)):
    list_of_dict = []
    if type(dataframe['Category'][i]) == str:
        list_of_category = dataframe['Category'][i].split(',')
        for item in list_of_category:
            dict_of_category = {'category':item}
            list_of_dict.append(dict_of_category)
    dataframe['Category'][i] = list_of_dict

# %%
jsonlist = []
for i in range(len(dataframe)):
    aItem = {}
    aItem["id"] = i
    aItem["Activity"] = dataframe['Activity'][i]
    aItem['OpenTime'] = dataframe['Day'][i]
    aItem["Category"] = dataframe['Category'][i]
    aItem['Address'] = dataframe['Address'][i]
    aItem['Phone'] = dataframe['Contact'][i]
    aItem['Website'] = dataframe['Website'][i]
    aItem['Email'] = dataframe['Email'][i]
    aItem['desc'] = dataframe['Description'][i]
    aItem['lat'] = dataframe['lat'][i]
    aItem['lng'] = dataframe['lng'][i]
    aJson = json.dumps(aItem, cls=ComplexEncoder)
    jsonlist.append(aItem)

# %%
savefile = 'well-being activities.json'

with open(savefile, 'w') as f:
    f.write(json.dumps(jsonlist, cls=ComplexEncoder))
